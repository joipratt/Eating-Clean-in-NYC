# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# File to Load (Remember to Change These)
restaurant_data = "Data/DOHMH_New_York_City_Restaurant_Inspection_Results.csv"
#rat_data = "Rat_Sightings.csv"

restaurant_data = pd.read_csv(restaurant_data)
#rat_data = pd.read_csv(rat_data)

restaurant_data.head()
# Out:
#       CAMIS                      DBA           BORO BUILDING         STREET  \
# 0  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 1  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 2  50046354                 VITE BAR         QUEENS     2507       BROADWAY
# 3  50061389  TACK'S CHINESE TAKE OUT  STATEN ISLAND      11C    HOLDEN BLVD
# 4  41516263               NO QUARTER       BROOKLYN     8015       5 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  10016.0  2126863400             Italian      06/15/2015
# 1  10016.0  2126863400             Italian      11/25/2014
# 2  11106.0  3478134702             Italian      10/03/2016
# 3  10314.0  7189839854             Chinese      05/17/2017
# 4  11209.0  7187019180            American      03/30/2017
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            02B
# 1  Violations were cited in the following area(s).            20F
# 2  Violations were cited in the following area(s).            10F
# 3  Violations were cited in the following area(s).            02G
# 4  Violations were cited in the following area(s).            04M
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0        Hot food item not held at or above 140Âº F.      Critical   30.0
# 1              Current letter grade card not posted.  Not Critical    NaN
# 2  Non-food contact surface improperly constructe...  Not Critical    2.0
# 3  Cold food item held above 41Âº F (smoked fish ...      Critical   46.0
# 4  Live roaches present in facility's food and/or...      Critical   18.0
#
#   GRADE GRADE DATE RECORD DATE  \
# 0   NaN        NaN  08/28/2017
# 1   NaN        NaN  08/28/2017
# 2   NaN        NaN  08/28/2017
# 3   NaN        NaN  08/28/2017
# 4   NaN        NaN  08/28/2017
#
#                                      INSPECTION TYPE
# 0              Cycle Inspection / Initial Inspection
# 1  Administrative Miscellaneous / Initial Inspection
# 2      Pre-permit (Operational) / Initial Inspection
# 3      Pre-permit (Operational) / Initial Inspection
# 4              Cycle Inspection / Initial Inspection

# %%
# Get the number of critical violations each restaurant has received

restaurant_data_1 = restaurant_data.loc[restaurant_data["CRITICAL FLAG"] == "Critical",:]
critical_violations_count = restaurant_data_1.groupby(restaurant_data_1["CAMIS"]).count()["CRITICAL FLAG"]

critical_violations_count.head()
# Out:
# CAMIS
# 30075445     3
# 30112340    13
# 30191841     7
# 40356018     2
# 40356151     8
# Name: CRITICAL FLAG, dtype: int64

# %%
# make a data frame with each individual restaurant with the information from their most recent violation

sorted_restaurant_data = restaurant_data_1.sort_values("INSPECTION DATE")
sorted_restaurant_data = sorted_restaurant_data.drop_duplicates(subset = "CAMIS", keep = "last")
sorted_restaurant_data = sorted_restaurant_data[["CAMIS","DBA","BORO","BUILDING","STREET","ZIPCODE","CUISINE DESCRIPTION","GRADE","GRADE DATE"]]
sorted_restaurant_data
# Out:
#            CAMIS                                    DBA       BORO  BUILDING  \
# 211966  50057961                         Sunnyside Taco     QUEENS      4222
# 118053  50056895                  MAXWELLS CHOPHOUSE NY  MANHATTAN      1182
# 36237       GRAND CENTRAL PKWY  11005.0
# 118521                5 AVENUE  11209.0
# 261534        EAST   13 STREET  10003.0
# 89109         EAST   52 STREET  10022.0
# 177401      LEFFERTS BOULEVARD  11415.0
# 18414         VAN BRUNT STREET  11231.0
# 75601           JAMAICA AVENUE  11421.0
#
#                                       CUISINE DESCRIPTION GRADE  GRADE DATE
# 211966                                            Mexican     A  01/03/2017
# 118053                                           American     A  01/03/2017
# 253465                                             Bakery     A  01/03/2017
# 220854                                              Pizza   NaN         NaN
# 273148                                          Soul Food     A  01/03/2017
# 365325                                             Donuts     A  01/03/2017
# 310948                                              Other     A  01/03/2017
# 266402                                            Chinese     A  01/03/2017
# 100209                                            Italian     A  01/04/2016
# 385117                                   CafÃ©/Coffee/Tea     A  01/04/2017
# 95012                                            American     A  01/04/2017
# 52251                                        Delicatessen     A  01/04/2017
# 374820                                              Other     A  01/04/2017
# 287051                                            Chicken     A  01/04/2017
# 225140                                             Donuts     A  01/04/2017
# 94622                                             Chinese     A  01/04/2017
# 69400                                               Other     A  01/04/2017
# 20227                     Ice Cream, Gelato, Yogurt, Ices     A  01/04/2017
# 100746                                            Spanish     A  01/04/2017
# 27367                                               Asian     A  01/04/2017
# 117231                                            Chinese   NaN         NaN
# 263633                                           American     A  01/04/2017
# 87853                                               Pizza     A  01/04/2017
# 240520                     Juice, Smoothies, Fruit Salads     A  01/04/2017
# 137426                                            Tex-Mex     A  01/05/2015
# 9208                                           Hamburgers     A  01/05/2015
# 303996                                           American     A  01/05/2016
# 61520                                            American     A  01/05/2016
# 212426                                           American     A  01/05/2016
# 210221                                   CafÃ©/Coffee/Tea     A  01/05/2017
# ...                                                   ...   ...         ...
# 278689                                              Pizza     A  12/31/2015
# 161363                                          Caribbean   NaN         NaN
# 379192                                    Bagels/Pretzels     A  12/31/2015
# 316482                                       Delicatessen     A  12/31/2015
# 251840                                   CafÃ©/Coffee/Tea     A  12/31/2015
# 48713                                             Spanish   NaN         NaN
# 102759                                             Bakery     A  12/31/2015
# 308470                                           American     A  12/31/2015
# 285013                                             Bakery     B  12/31/2015
# 47242                                             Chinese   NaN         NaN
# 91160                                            American     A  12/31/2015
# 36494   Latin (Cuban, Dominican, Puerto Rican, South &...     B  12/31/2015
# 340960                                           American   NaN         NaN
# 12177                       Vietnamese/Cambodian/Malaysia   NaN         NaN
# 225051  Latin (Cuban, Dominican, Puerto Rican, South &...   NaN         NaN
# 336728                                              Pizza     A  12/31/2015
# 396236  Latin (Cuban, Dominican, Puerto Rican, South &...   NaN         NaN
# 261516                                           American   NaN         NaN
# 71388   Latin (Cuban, Dominican, Puerto Rican, South &...   NaN         NaN
# 273955                                          Caribbean     A  12/31/2015
# 41122                                        Delicatessen     A  12/31/2015
# 361677                                    Bagels/Pretzels     A  12/31/2015
# 106429                                            Chinese     B  12/31/2015
# 36237                                         Continental   NaN         NaN
# 118521                                         Sandwiches   NaN         NaN
# 261534                                             French   NaN         NaN
# 89109                                            American   NaN         NaN
# 177401                                              Pizza   NaN         NaN
# 18414                                            American     A  12/31/2016
# 75601                                            American   NaN         NaN
#
# [24632 rows x 9 columns]

# %%
# pull in the count of critical violations each restaurant received

restaurant_summary = pd.merge(sorted_restaurant_data,critical_violations_count,how = "left", on = ["CAMIS","CAMIS"])
restaurant_summary = restaurant_summary.rename(columns  = {"CRITICAL FLAG":"Count of Violations"})

# %%
# read Rat Sightings csv, which was made in another notebook

Rat_Sightings = pd.read_csv("Data/Rat_Sightings.csv")
Rat_Sightings = Rat_Sightings.rename(columns  = {"Incident Zip":"ZIPCODE"})
Rat_Sightings.head()
# Out:
#    ZIPCODE  Rat Sightings
# 0  10000.0              3
# 1  10001.0            383
# 2  10002.0           1299
# 3  10003.0            627
# 4  10004.0             40

# %%
restaurant_summary = pd.merge(restaurant_summary,Rat_Sightings,how = "left", on = ["ZIPCODE","ZIPCODE"])

# %%
#need to clear NA's out of violations, rat sightings and grade for a cleaner data set

restaurant_summary = restaurant_summary.dropna(subset=['GRADE'])
restaurant_summary = restaurant_summary.dropna(subset=['Count of Violations'])
restaurant_summary = restaurant_summary.dropna(subset=['Rat Sightings'])

pd.options.mode.chained_assignment = None 
restaurant_summary["Rat Sightings"] = restaurant_summary["Rat Sightings"].astype(int)
restaurant_summary["ZIPCODE"] = restaurant_summary["ZIPCODE"].astype(int)
restaurant_summary.head()
# Out:
#       CAMIS                    DBA       BORO BUILDING          STREET  \
# 0  50057961         Sunnyside Taco     QUEENS     4222  GREENPOINT AVE
# 1  50056895  MAXWELLS CHOPHOUSE NY  MANHATTAN     1182        BROADWAY
# 2  50057019         PARIS BAGUETTE     QUEENS     4522         46TH ST
# 4  50050701    FREDERICK SOUL HOLE     QUEENS   23316A    MERRICK BLVD
# 5  50057533          DUNKIN DONUTS  MANHATTAN      750         8TH AVE
#
#    ZIPCODE CUISINE DESCRIPTION GRADE  GRADE DATE  Count of Violations  \
# 0    11104             Mexican     A  01/03/2017                    1
# 1    10001            American     A  01/03/2017                    1
# 2    11104              Bakery     A  01/03/2017                    1
# 4    11422           Soul Food     A  01/03/2017                    1
# 5    10036              Donuts     A  01/03/2017                    1
#
#    Rat Sightings
# 0            186
# 1            383
# 2            186
# 4            107
# 5            533

# %%
# compare average violations by zipcode with the number of rat sightings by zipcode

average_violations = restaurant_summary.groupby(["ZIPCODE","BORO"]).mean()
average_violations = average_violations.reset_index()
average_violations = average_violations[["ZIPCODE","BORO","Count of Violations"]]                                       
Rat_Sightings = Rat_Sightings.astype(int)
rats_and_violations = pd.merge(average_violations,Rat_Sightings, on = "ZIPCODE", how="left")
rV_manhattan = rats_and_violations.loc[rats_and_violations["BORO"] == "MANHATTAN",:]
rV_brooklyn = rats_and_violations.loc[rats_and_violations["BORO"] == "BROOKLYN",:]
rV_queens = rats_and_violations.loc[rats_and_violations["BORO"] == "QUEENS",:]
rV_bronx = rats_and_violations.loc[rats_and_violations["BORO"] == "BRONX",:]
rV_staten_island = rats_and_violations.loc[rats_and_violations["BORO"] == "STATEN ISLAND",:]

# %%
plt.scatter(rats_and_violations["Count of Violations"],rats_and_violations["Rat Sightings"])
plt.xlabel("Average Violations")
plt.ylabel("Rat Sightings")
plt.title("Violations and Rat Sightings by Zipcode")
plt.savefig("Violations_and_Rat_Sightings_by_Zipcode")

# %%
plt.scatter(rV_manhattan["Count of Violations"],rV_manhattan["Rat Sightings"])
plt.xlabel("Average Violations")
plt.ylabel("Rat Sightings")
plt.title("Violations and Rat Sightings by Zipcode in Manhattan")
plt.savefig("Violations_and_Rat_Sightings_by_Zipcode_in_Manhattan")

# %%
plt.scatter(rV_brooklyn["Count of Violations"],rV_brooklyn["Rat Sightings"])
plt.xlabel("Average Violations")
plt.ylabel("Rat Sightings")
plt.title("Violations and Rat Sightings by Zipcode in Brooklyn")
plt.savefig("Violations_and_Rat_Sightings_by_Zipcode_in_Brooklyn")

# %%
plt.scatter(rV_queens["Count of Violations"],rV_queens["Rat Sightings"])
plt.xlabel("Average Violations")
plt.ylabel("Rat Sightings")
plt.title("Violations and Rat Sightings by Zipcode in Queens")
plt.savefig("Violations_and_Rat_Sightings_by_Zipcode_in_Queens")

# %%
plt.scatter(rV_staten_island["Count of Violations"],rV_staten_island["Rat Sightings"])
plt.xlabel("Average Violations")
plt.ylabel("Rat Sightings")
plt.title("Violations and Rat Sightings by Zipcode in Staten Island")
plt.savefig("Violations_and_Rat_Sightings_by_Zipcode_in_Staten_Island")

# %%
plt.scatter(rV_bronx["Count of Violations"],rV_bronx["Rat Sightings"])
plt.xlabel("Average Violations")
plt.ylabel("Rat Sightings")
plt.title("Violations and Rat Sightings by Zipcode in Bronx")
plt.savefig("Violations_and_Rat_Sightings_by_Zipcode_in_Bronx")

# %%
# visualize the % of total violations that were critical each year

restaurant_data["YEAR"] = pd.DatetimeIndex(restaurant_data["INSPECTION DATE"]).year

total_violations_peryear = restaurant_data.groupby(["YEAR"]).count()["CRITICAL FLAG"]
tot_viol_df = pd.DataFrame(total_violations_peryear)
critical_violations = restaurant_data.loc[restaurant_data["CRITICAL FLAG"] =="Critical"]
cri_vio_by_year = critical_violations.groupby([restaurant_data["YEAR"]]).count()["CRITICAL FLAG"]
critical_vio_summary = pd.merge(cri_vio_by_year,tot_viol_df,on = "YEAR")
critical_vio_summary.rename(columns = {'CRITICAL FLAG_x':'critical violations count', 'CRITICAL FLAG_y':'total violations'}, inplace = True)
critical_vio_summary["% to Total"]= critical_vio_summary["critical violations count"]/critical_vio_summary["total violations"] *100
critical_vio_summary
percent_list = critical_vio_summary['% to Total'].tolist()
percent_list.remove(55.55555555555556)
percent_list
# Out:
# [53.90542907180386,
#  54.625605057789194,
#  54.844116087767006,
#  55.49878072949428,
#  55.91244198839136]

# %%
years = ("2013","2014","2015","2016","2017")
y_pos = np.arange(len(years))
plt.bar(y_pos, percent_list, align='center', alpha=0.5)
plt.xticks(y_pos, years)
plt.ylabel('Critical Violations %')
plt.ylim(50,58)
plt.title('Critical Violations % to Total Violations By Year')
plt.savefig("Critical_Violations_%_by_Year")

# %%
# make algorithm to create our restaurant rating

# Grade Value

restaurant_summary["Grade Value"] = 0
restaurant_summary["Grade Value"][restaurant_summary["GRADE"] == "A"] = 3
restaurant_summary["Grade Value"][restaurant_summary["GRADE"] == "B"] = 2
restaurant_summary["Grade Value"][restaurant_summary["GRADE"] == "C"] = 1
restaurant_summary["Grade Value"][restaurant_summary["GRADE"] == "Z"] = 1
restaurant_summary["Grade Value"][restaurant_summary["GRADE"] == "Not Yet Graded"] = 1
restaurant_summary["Grade Value"][restaurant_summary["GRADE"] == "P"] = 0

# Rat Sightings Value

rat_bin = [0,100,250,500,1000,2000,5000]
rat_grade = ["5","4","3","2","1","0"]

restaurant_summary["RT Value"] = pd.cut(restaurant_summary["Rat Sightings"],rat_bin, labels = rat_grade)

# Violations Value

vio_bin = [0,2,5,10,20,30,100]
vio_grade = ["5","4","3","2","1","0"]

restaurant_summary["Vio Value"] = pd.cut(restaurant_summary["Count of Violations"],vio_bin, labels = vio_grade)

pd.options.mode.chained_assignment = None 
restaurant_summary["Vio Value"] = restaurant_summary["Vio Value"].astype(int)
restaurant_summary["RT Value"] = restaurant_summary["RT Value"].astype(int)

restaurant_summary["Grade(%)"] = (restaurant_summary["Grade Value"] + restaurant_summary["RT Value"] + restaurant_summary["Vio Value"])/13

restaurant_summary = restaurant_summary.sort_values(by = "Grade(%)",ascending = True)

restaurant_summary
# Out:
#           CAMIS                                   DBA       BORO BUILDING  \
# 20649  50015614                   TOTAL AMAZING GRACE   BROOKLYN     3113
# 20092  50006110                             ARCO CAFE  MANHATTAN      886
# 17841  50001701                           CHINA XIANG  MANHATTAN      360
# 21236  40378347                          TONY'S PIZZA      BRONX     1014
# 24508  41303170                     JC MAR RESTAURANT   BROOKLYN      736
# 21909  50016943              EL NUEVO ROBLE BILLIARDS      BRONX      216
# 12425  41083735             PLAZA TULCINGO RESTAURANT      BRONX       10
# 19806  41474882                                  BUKA   BROOKLYN      946
# 16035  41587826                     CASCABEL TAQUERIA  MANHATTAN     2799
# 16450  40692120                        NEW ROMA PIZZA  MANHATTAN      116
# 23596  50000198                       SZECHUAN GARDEN  MANHATTAN      239
# 24175  41721069               MASAKI TERIYAKI & SUSHI   BROOKLYN       11
# 17950  50005934                          MIYAKO SUSHI  MANHATTAN      642
# 15568  41343181               TAQUERIA DE LOS MUERTOS   BROOKLYN      663
# 18349  41127647                           BURRITO BAR   BROOKLYN   307311
# 20804  41583191                    QUEZADA RESTAURANT   BROOKLYN     1212
# 19890  40397574           DOMINICK'S BAR & RESTAURANT      BRONX     2335
# 19673  41612180                              WOODLAND   BROOKLYN      242
# 22188  41705634        EXPRESS BROOK LUNCH RESTAURANT      BRONX      502
# 18334  41653879                         LENOX SAPHIRE  MANHATTAN      341
# 8063                     1             66            3         5          5
# 7916                     2             77            3         5          5
# 7900                     1             77            3         5          5
# 3841                     1             18            3         5          5
# 985                      2             80            3         5          5
# 7747                     2             10            3         5          5
# 471                      2             77            3         5          5
# 18886                    2             77            3         5          5
# 8811                     2             29            3         5          5
# 8933                     2             77            3         5          5
# 379                      1             10            3         5          5
# 3008                     2             77            3         5          5
# 23528                    2             40            3         5          5
# 3025                     2             77            3         5          5
# 3049                     1             72            3         5          5
# 9894                     1             77            3         5          5
# 18513                    2             40            3         5          5
# 1097                     1              1            3         5          5
# 9802                     2             10            3         5          5
# 3150                     2             77            3         5          5
# 9478                     2             21            3         5          5
# 9379                     1             97            3         5          5
# 1056                     2             77            3         5          5
# 9229                     2              2            3         5          5
# 21776                    2             40            3         5          5
# 3360                     2             41            3         5          5
# 3080                     1             65            3         5          5
# 23203                    1             85            3         5          5
#
#        Grade(%)
# 20649  0.076923
# 20092  0.076923
# 17841  0.153846
# 21236  0.153846
# 24508  0.153846
# 21909  0.153846
# 12425  0.153846
# 19806  0.153846
# 16035  0.153846
# 16450  0.153846
# 23596  0.153846
# 24175  0.153846
# 17950  0.153846
# 15568  0.230769
# 18349  0.230769
# 20804  0.230769
# 19890  0.230769
# 19673  0.230769
# 22188  0.230769
# 18334  0.230769
# 22207  0.230769
# 19055  0.230769
# 23822  0.230769
# 23175  0.230769
# 23239  0.230769
# 22672  0.230769
# 20803  0.230769
# 22569  0.230769
# 9249   0.230769
# 22110  0.230769
# ...         ...
# 8159   1.000000
# 8124   1.000000
# 8063   1.000000
# 7916   1.000000
# 7900   1.000000
# 3841   1.000000
# 985    1.000000
# 7747   1.000000
# 471    1.000000
# 18886  1.000000
# 8811   1.000000
# 8933   1.000000
# 379    1.000000
# 3008   1.000000
# 23528  1.000000
# 3025   1.000000
# 3049   1.000000
# 9894   1.000000
# 18513  1.000000
# 1097   1.000000
# 9802   1.000000
# 3150   1.000000
# 9478   1.000000
# 9379   1.000000
# 1056   1.000000
# 9229   1.000000
# 21776  1.000000
# 3360   1.000000
# 3080   1.000000
# 23203  1.000000
#
# [19091 rows x 15 columns]

# %%
# Boro table
boro = restaurant_summary[["BORO","Rat Sightings","Count of Violations","ZIPCODE"]]

boro_rats = boro.groupby("BORO")["Rat Sightings"].sum()
boro_rats = boro_rats.reset_index()
boro_rats = boro_rats.sort_values(by = "Rat Sightings",ascending = False)

boro_vio = boro.groupby("BORO")["Count of Violations"].sum()
boro_vio = boro_vio.reset_index()
boro_vio = boro_vio.sort_values(by = "Count of Violations",ascending = False)

boro_count = boro.groupby("BORO")["ZIPCODE"].count()
boro_count = boro_count.reset_index()
boro_count = boro_count.sort_values(by = "ZIPCODE",ascending = False)
boro_count
# Out:
#             BORO  ZIPCODE
# 2      MANHATTAN     7490
# 1       BROOKLYN     4706
# 3         QUEENS     4412
# 0          BRONX     1799
# 4  STATEN ISLAND      684

# %%
# cuisine table
cuisine = restaurant_summary[["CUISINE DESCRIPTION","Rat Sightings","Count of Violations"]]

cuisine_rats = cuisine.groupby("CUISINE DESCRIPTION")["Rat Sightings"].sum()
cuisine_rats = cuisine_rats.reset_index()
cuisine_rats = cuisine_rats.sort_values(by = "Rat Sightings",ascending = False)

cuisine_vio = cuisine.groupby("CUISINE DESCRIPTION")["Count of Violations"].sum()
cuisine_vio = cuisine_vio.reset_index()
cuisine_vio = cuisine_vio.sort_values(by = "Count of Violations",ascending = False)

# %%
grade = restaurant_summary[["GRADE","Rat Sightings","Count of Violations"]]

grade_rat = grade.groupby("GRADE")["Rat Sightings"].sum()
grade_rat = grade_rat.reset_index()

grade_vio = grade.groupby("GRADE")["Count of Violations"].sum()
grade_vio = grade_vio.reset_index()

# %%
plt.bar(grade_rat["GRADE"],grade_rat["Rat Sightings"],align = "center", color = "navy")
plt.title("Rat Sightings per Grade")
plt.ylabel("Rat Sightings")
plt.xlabel("Grade")
plt.savefig("Rat Sightings Per Grade")

# %%
plt.bar(grade_vio["GRADE"],grade_vio["Count of Violations"],align = "center", color = "navy")
plt.title("Violations per Grade")
plt.ylabel("Violations")
plt.xlabel("Grade")
plt.savefig("Violations per Grade")

# %%
#total data 
plt.scatter(restaurant_summary["Count of Violations"],restaurant_summary["Rat Sightings"],marker = "x")
plt.title("Rat Sightings v Violations - NYC")
plt.xlabel("Violations")
plt.ylabel("Rat Sightings")
plt.grid(True)
plt.savefig("Rat Sightings v Violations - NYC")

# %%
# DF filtered by boro
restaurant_summary_bk = restaurant_summary[restaurant_summary["BORO"] == "BROOKLYN"]
restaurant_summary_qu = restaurant_summary[restaurant_summary["BORO"] == "QUEENS"]
restaurant_summary_bx = restaurant_summary[restaurant_summary["BORO"] == "BRONX"]
restaurant_summary_si = restaurant_summary[restaurant_summary["BORO"] == "STATEN ISLAND"]
restaurant_summary_mh = restaurant_summary[restaurant_summary["BORO"] == "MANHATTAN"]

# %%
restaurant_summary_bk_grade = restaurant_summary_bk[["BORO","CUISINE DESCRIPTION","DBA","BUILDING","STREET","ZIPCODE","Grade(%)"]]
restaurant_summary_bk_grade.head()
# Out:
#            BORO CUISINE DESCRIPTION                      DBA BUILDING  \
# 20649  BROOKLYN           Caribbean      TOTAL AMAZING GRACE     3113
# 24508  BROOKLYN             Spanish        JC MAR RESTAURANT      736
# 19806  BROOKLYN             African                     BUKA      946
# 24175  BROOKLYN            Japanese  MASAKI TERIYAKI & SUSHI       11
# 15568  BROOKLYN             Mexican  TAQUERIA DE LOS MUERTOS      663
#
#                   STREET  ZIPCODE  Grade(%)
# 20649         CHURCH AVE    11226  0.076923
# 24508    NOSTRAND AVENUE    11216  0.153846
# 19806      FULTON STREET    11238  0.153846
# 24175      PUTNAM AVENUE    11238  0.153846
# 15568  WASHINGTON AVENUE    11238  0.230769

# %%
restaurant_summary_qu_grade = restaurant_summary_qu[["BORO","CUISINE DESCRIPTION","DBA","BUILDING","STREET","ZIPCODE","Grade(%)"]]
restaurant_summary_qu_grade.head()
# Out:
#          BORO                                CUISINE DESCRIPTION  \
# 21379  QUEENS  Latin (Cuban, Dominican, Puerto Rican, South &...
# 20861  QUEENS                                            Chicken
# 20723  QUEENS                                             Indian
# 10798  QUEENS  Latin (Cuban, Dominican, Puerto Rican, South &...
# 6231   QUEENS                                            Tex-Mex
#
#                              DBA BUILDING         STREET  ZIPCODE  Grade(%)
# 21379         JORGE'S RESTAURANT      689  SENECA AVENUE    11385  0.230769
# 20861        CROWN FRIED CHICKEN      701     SENECA AVE    11385  0.307692
# 20723           NEW TANDOORI HUT    11908       94TH AVE    11419  0.307692
# 10798                    CHIFLEZ     9502  ROOSEVELT AVE    11372  0.307692
# 6231   TASTE OF TACO/YUMMY CHINA     6841     MYRTLE AVE    11385  0.307692

# %%
restaurant_summary_bx_grade = restaurant_summary_bx[["BORO","CUISINE DESCRIPTION","DBA","BUILDING","STREET","ZIPCODE","Grade(%)"]]
restaurant_summary_bx_grade.head()
# Out:
#         BORO CUISINE DESCRIPTION                             DBA BUILDING  \
# 21236  BRONX            American                    TONY'S PIZZA     1014
# 21909  BRONX             Spanish        EL NUEVO ROBLE BILLIARDS      216
# 12425  BRONX             Mexican       PLAZA TULCINGO RESTAURANT       10
# 19890  BRONX             Italian     DOMINICK'S BAR & RESTAURANT     2335
# 22188  BRONX             Spanish  EXPRESS BROOK LUNCH RESTAURANT      502
#
#                   STREET  ZIPCODE  Grade(%)
# 21236    LONGWOOD AVENUE    10459  0.153846
# 21909         E 170TH ST    10456  0.153846
# 12425  EAST CLARKE PLACE    10452  0.153846
# 19890      ARTHUR AVENUE    10458  0.230769
# 22188   EAST  138 STREET    10454  0.230769

# %%
restaurant_summary_si_grade = restaurant_summary_si[["BORO","CUISINE DESCRIPTION","DBA","BUILDING","STREET","ZIPCODE","Grade(%)"]]
restaurant_summary_si_grade.head()
# Out:
#                 BORO CUISINE DESCRIPTION                DBA BUILDING  \
# 21220  STATEN ISLAND             Chinese      NEW YUNG HONG     2491
# 21140  STATEN ISLAND               Pizza  CHUCK E. CHEESE'S     1775
# 12747  STATEN ISLAND            Japanese        SARKU JAPAN     2655
# 15656  STATEN ISLAND       Pizza/Italian    MY FAMILY PIZZA     1032
# 17105  STATEN ISLAND        Delicatessen     658 KINGS DELI      658
#
#                  STREET  ZIPCODE  Grade(%)
# 21220      VICTORY BLVD    10314  0.307692
# 21140      SOUTH AVENUE    10314  0.307692
# 12747   RICHMOND AVENUE    10314  0.384615
# 15656  CASTLETON AVENUE    10310  0.384615
# 17105     NEW DORP LANE    10306  0.384615

# %%
restaurant_summary_mh_grade = restaurant_summary_mh[["BORO","CUISINE DESCRIPTION","DBA","BUILDING","STREET","ZIPCODE","Grade(%)"]]
restaurant_summary_mh_grade.head()
# Out:
#             BORO CUISINE DESCRIPTION                DBA BUILDING  \
# 20092  MANHATTAN             Italian          ARCO CAFE      886
# 17841  MANHATTAN               Asian        CHINA XIANG      360
# 16035  MANHATTAN             Mexican  CASCABEL TAQUERIA     2799
# 16450  MANHATTAN               Pizza     NEW ROMA PIZZA      116
# 23596  MANHATTAN             Chinese    SZECHUAN GARDEN      239
#
#                STREET  ZIPCODE  Grade(%)
# 20092   AMSTERDAM AVE    10025  0.076923
# 17841       W 42ND ST    10036  0.153846
# 16035        BROADWAY    10025  0.153846
# 16450  DELANCY STREET    10002  0.153846
# 23596      W 105TH ST    10025  0.153846

# %%
cuisine_grade = restaurant_summary[["CUISINE DESCRIPTION","BORO","DBA","BUILDING","STREET","ZIPCODE","Grade(%)"]]
cuisine_grade.head()
# Out:
#       CUISINE DESCRIPTION       BORO                  DBA BUILDING  \
# 20649           Caribbean   BROOKLYN  TOTAL AMAZING GRACE     3113
# 20092             Italian  MANHATTAN            ARCO CAFE      886
# 17841               Asian  MANHATTAN          CHINA XIANG      360
# 21236            American      BRONX         TONY'S PIZZA     1014
# 24508             Spanish   BROOKLYN    JC MAR RESTAURANT      736
#
#                 STREET  ZIPCODE  Grade(%)
# 20649       CHURCH AVE    11226  0.076923
# 20092    AMSTERDAM AVE    10025  0.076923
# 17841        W 42ND ST    10036  0.153846
# 21236  LONGWOOD AVENUE    10459  0.153846
# 24508  NOSTRAND AVENUE    11216  0.153846

# %%
plt.scatter(restaurant_summary_bk["Count of Violations"],restaurant_summary_bk["Rat Sightings"],marker = "o")
plt.title("Rat Sightings v Violations - Brooklyn")
plt.xlabel("Violations")
plt.ylabel("Rat Sightings")
plt.grid(True)
plt.savefig("Rat Sightings v Violations - Brooklyn")

# %%
plt.scatter(restaurant_summary_qu["Count of Violations"],restaurant_summary_qu["Rat Sightings"],marker = "x")
plt.title("Rat Sightings v Violations - Queens")
plt.xlabel("Violations")
plt.ylabel("Rat Sightings")
plt.grid(True)
plt.savefig("Rat Sightings v Violations - Queens")

# %%
plt.scatter(restaurant_summary_bx["Count of Violations"],restaurant_summary_bx["Rat Sightings"],marker = "x")
plt.title("Rat Sightings v Violations - Bronx")
plt.xlabel("Violations")
plt.ylabel("Rat Sightings")
plt.grid(True)
plt.savefig("Rat Sightings v Violations - Bronx")

# %%
plt.scatter(restaurant_summary_si["Count of Violations"],restaurant_summary_si["Rat Sightings"],marker = "x")
plt.title("Rat Sightings v Violations - Staten Island")
plt.xlabel("Violations")
plt.ylabel("Rat Sightings")
plt.grid(True)
plt.savefig("Rat Sightings v Violations - Staten Island")

# %%
plt.scatter(restaurant_summary_mh["Count of Violations"],restaurant_summary_mh["Rat Sightings"],marker = "x")
plt.title("Rat Sightings v Violations - Manhattan")
plt.xlabel("Violations")
plt.ylabel("Rat Sightings")
plt.grid(True)
plt.savefig("Rat Sightings v Violations - Manhattan")

# %%
# ran a linear regression to check statistical significance of rat sightings on number of violations

vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(
    restaurant_summary["Count of Violations"], restaurant_summary["Rat Sightings"])

vc_p

# the P value is too small to claim that the number of rat sightings is significant to how many violations a restaurant has
# Out:
# 0.23684886467076952
